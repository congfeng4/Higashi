# %%
# 1. 安装（仅需一次）
# pip install umap-learn matplotlib

# 2. 完整演示
import umap
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

# 载入数据
digits = load_digits()
X, y = digits.data, digits.target          # 1 797 张 8×8 手写数字

# 3. UMAP 降维 → 2D
embedding = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42).fit_transform(X)

# 4. 可视化
plt.figure(figsize=(6, 5))
plt.scatter(embedding[:, 0], embedding[:, 1],
            c=y, cmap='Spectral', s=15, alpha=0.8)
plt.colorbar(label='Digit Class')
plt.title('UMAP projection of Digits dataset')
plt.tight_layout(); plt.show()
# Out:
# /public/congfeng4/miniconda3/envs/py39/lib/python3.9/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
